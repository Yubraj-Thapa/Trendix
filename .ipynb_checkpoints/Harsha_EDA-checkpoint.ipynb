# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Trendix_Dataset.csv")

# %%
df.head()
# Out:
#    Serial_No Fashion_type  Product_id         Brand_Name        category  \
# 0          1      blazers  17464542.0                H&M  women-clothing
# 1          2      blazers  24970972.0  Allen Solly Woman  women-clothing
# 2          3      blazers  26893598.0              Arrow    men-clothing
# 3          4      blazers  28844176.0              MANGO  women-clothing
# 4          5      blazers  28774520.0              MANGO  women-clothing
#
#                                          Description  Rating Rating_count  \
# 0                          Women Black Fitted Jacket     4.4   951Ratings
# 1  Notched Lapel Collar Single-Breasted Formal Bl...     4.3   643Ratings
# 2  Notched Lapel Long Sleeves Slim-Fit Single Bre...     4.2   161Ratings
# 3                     Pure Linen Smart Casual Blazer     4.1    37Ratings
# 4  Smart Casual Linen Notched Lapel Single-Breast...     4.0    43Ratings
#
#     Price  Actual_Price   Discount  \
# 0  2299.0           NaN        NaN
# 1  3959.0        3999.0   (1% OFF)
# 2  4879.0        7999.0  (39% OFF)
# 3  6790.0           NaN        NaN
# 4  4549.0        6790.0  (33% OFF)
#
#                                                size  \
# 0  ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL']
# 1                                               NaN
# 2              ['36', '38', '40', '42', '44', '46']
# 3         ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL']
# 4                ['XS', 'S', 'M', 'L', 'XL', 'XXL']
#
#                                  product_description  \
# 0  Fitted jacket in woven fabric with notch lapel...
# 1  Black solid regular-fit formal blazer, has a n...
# 2  Black solid slim-fit formal blazer, has a notc...
# 3  Blue solid smart casual blazer, has a peaked l...
# 4  The solid blazers for women, has notched lapel...
#
#                              image_ref  \
# 0  blazers_women-clothing_17464542.jpg
# 1  blazers_women-clothing_24970972.jpg
# 2    blazers_men-clothing_26893598.jpg
# 3  blazers_women-clothing_28844176.jpg
# 4  blazers_women-clothing_28774520.jpg
#
#                                            file_path  \
# 0  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 1  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 2  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 3  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 4  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
#
#                                            image_url  \
# 0  https://assets.myntassets.com/h_720,q_90,w_540...
# 1  https://assets.myntassets.com/h_720,q_90,w_540...
# 2  https://assets.myntassets.com/h_720,q_90,w_540...
# 3  https://assets.myntassets.com/h_720,q_90,w_540...
# 4  https://assets.myntassets.com/h_720,q_90,w_540...
#
#                                       Specifications  \
# 0  {'Closure': 'Button', 'Collar': 'Notched Lapel...
# 1  {'Closure': 'Button', 'Collar': 'Notched Lapel...
# 2  {'Closure': 'Button', 'Collar': 'Notched Lapel...
# 3  {'Closure': 'Button', 'Collar': 'Peaked Lapel'...
# 4  {'Closure': 'Button', 'Collar': 'Notched Lapel...
#
#                                      Rating_as_stars
# 0  {'5': '645', '4': '176', '3': '62', '2': '27',...
# 1  {'5': '421', '4': '113', '3': '29', '2': '21',...
# 2  {'5': '98', '4': '29', '3': '11', '2': '9', '1...
# 3  {'5': '26', '4': '2', '3': '1', '2': '2', '1':...
# 4  {'5': '30', '4': '2', '3': '1', '2': '3', '1':...

# %%
df.tail()
# Out:
#        Serial_No       Fashion_type  Product_id               Brand_Name  \
# 24173        994  Women Office Wear  30111247.0           Style Quotient
# 24174        995  Women Office Wear  27631984.0                Chemistry
# 24175        996  Women Office Wear  29328582.0  Annabelle by Pantaloons
# 24176        997  Women Office Wear  29173318.0                 Cantabil
# 24177        998  Women Office Wear  28324258.0                   FITHUB
#
#              category                               Description  Rating  \
# 24173  women-clothing           Women Smart Opaque Formal Shirt     4.0
# 24174  women-clothing                      Striped Formal Shirt     4.2
# 24175  women-clothing                 Women Opaque Formal Shirt     4.6
# 24176  women-clothing                Spread Collar Formal Shirt     4.4
# 24177  women-clothing  Women Slim Fit High-Rise Formal Trousers     3.8
#
#       Rating_count   Price  Actual_Price   Discount  \
# 24173     6Ratings   636.0        1299.0  (51% OFF)
# 24174    43Ratings   499.0        1999.0  (75% OFF)
# 24175    22Ratings  1499.0           NaN        NaN
# 24176    31Ratings   899.0        1999.0  (55% OFF)
# 24177    55Ratings   899.0        1999.0  (55% OFF)
#
#                                              size  \
# 24173                       ['S', 'M', 'L', 'XL']
# 24174                 ['XS', 'S', 'M', 'XL', 'L']
# 24175          ['XS', 'S', 'M', 'L', 'XL', 'XXL']
# 24176         ['S', 'M', 'L', 'XL', 'XXL', '3XL']
# 24177  ['30', '32', '34', '36', '38', '40', '42']
#
#                                      product_description  \
# 24173  White solid opaque Formal shirt ,has a spread ...
# 24174  Black & white vertical striped opaque formal s...
# 24175  Blue solid opaque Formal shirt ,has a spread c...
# 24176  Green solid opaque Formal shirt ,has a spread ...
# 24177  Fit: Slim FitThe model (height 5'8) is wearing...
#
#                                            image_ref  \
# 24173  Women Office Wear_women-clothing_30111247.jpg
# 24174  Women Office Wear_women-clothing_27631984.jpg
# 24175  Women Office Wear_women-clothing_29328582.jpg
# 24176  Women Office Wear_women-clothing_29173318.jpg
# 24177  Women Office Wear_women-clothing_28324258.jpg
#
#                                                file_path  \
# 24173  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24174  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24175  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24176  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24177  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
#
#                                                image_url  \
# 24173  https://assets.myntassets.com/h_720,q_90,w_540...
# 24174  https://assets.myntassets.com/h_720,q_90,w_540...
# 24175  https://assets.myntassets.com/h_720,q_90,w_540...
# 24176  https://assets.myntassets.com/h_720,q_90,w_540...
# 24177  https://assets.myntassets.com/h_720,q_90,w_540...
#
#                                           Specifications  \
# 24173  {'Sleeve Length': 'Short Sleeves', 'Collar': '...
# 24174  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24175  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24176  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24177  {'Waist Rise': 'High-Rise', 'Length': 'Regular...
#
#                                          Rating_as_stars
# 24173  {'5': '3', '4': '1', '3': '1', '2': '1', '1': ''}
# 24174  {'5': '24', '4': '11', '3': '5', '2': '', '1':...
# 24175  {'5': '16', '4': '3', '3': '3', '2': '', '1': ''}
# 24176  {'5': '21', '4': '7', '3': '', '2': '', '1': '3'}
# 24177  {'5': '28', '4': '9', '3': '6', '2': '2', '1':...

# %%
#basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24178 entries, 0 to 24177
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Serial_No            24178 non-null  int64
#  1   Fashion_type         24178 non-null  object
#  2   Product_id           24144 non-null  float64
#  3   Brand_Name           24144 non-null  object
#  4   category             24144 non-null  object
#  5   Description          24142 non-null  object
#  6   Rating               21947 non-null  float64
#  7   Rating_count         21947 non-null  object
#  8   Price                24154 non-null  float64
#  9   Actual_Price         21294 non-null  float64
#  10  Discount             21283 non-null  object
#  11  size                 21319 non-null  object
#  12  product_description  24130 non-null  object
#  13  image_ref            24142 non-null  object
#  14  file_path            24142 non-null  object
#  15  image_url            24142 non-null  object
#  16  Specifications       24134 non-null  object
#  17  Rating_as_stars      20002 non-null  object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 3.3+ MB

# %%
# Example: Renaming specific columns
df.rename(columns={
    'Price': 'Price_After_Discount',
    'Actual_Price': 'MRP_Price'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['Serial_No', 'Fashion_type', 'Product_id', 'Brand_Name', 'category',
#        'Description', 'Rating', 'Rating_count', 'Price_After_Discount',
#        'MRP_Price', 'Discount', 'size', 'product_description', 'image_ref',
#        'file_path', 'image_url', 'Specifications', 'Rating_as_stars'],
#       dtype='object')

# %%
#summary statistics
df.describe()
# Out:
#           Serial_No    Product_id        Rating  Price_After_Discount  \
# count  24178.000000  2.414400e+04  21947.000000          24154.000000
# mean     745.369385  2.428805e+07      4.170684           1742.143165
# std      512.354450  6.038245e+06      0.363585           1987.131462
# min        1.000000  1.503240e+05      1.000000            179.000000
# 25%      318.000000  2.163112e+07      4.000000            728.000000
# 50%      662.000000  2.581962e+07      4.200000           1149.000000
# 75%     1081.000000  2.914472e+07      4.400000           1974.000000
# max     2000.000000  3.096750e+07      5.000000          70000.000000
#
#           MRP_Price
# count  21294.000000
# mean    3228.989668
# std     2253.140049
# min      299.000000
# 25%     1659.000000
# 50%     2499.000000
# 75%     3999.000000
# max    19999.000000

# %%
# Check for missing values in the DataFrame
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Serial_No                  0
# Fashion_type               0
# Product_id                34
# Brand_Name                34
# category                  34
# Description               36
# Rating                  2231
# Rating_count            2231
# Price_After_Discount      24
# MRP_Price               2884
# Discount                2895
# size                    2859
# product_description       48
# image_ref                 36
# file_path                 36
# image_url                 36
# Specifications            44
# Rating_as_stars         4176
# dtype: int64

# %% [markdown]
# ## Univariet Analysis

# %%
# Summary statistics for numerical features
df.describe()
# Out:
#           Serial_No    Product_id        Rating  Price_After_Discount  \
# count  24178.000000  2.414400e+04  21947.000000          24154.000000
# mean     745.369385  2.428805e+07      4.170684           1742.143165
# std      512.354450  6.038245e+06      0.363585           1987.131462
# min        1.000000  1.503240e+05      1.000000            179.000000
# 25%      318.000000  2.163112e+07      4.000000            728.000000
# 50%      662.000000  2.581962e+07      4.200000           1149.000000
# 75%     1081.000000  2.914472e+07      4.400000           1974.000000
# max     2000.000000  3.096750e+07      5.000000          70000.000000
#
#           MRP_Price
# count  21294.000000
# mean    3228.989668
# std     2253.140049
# min      299.000000
# 25%     1659.000000
# 50%     2499.000000
# 75%     3999.000000
# max    19999.000000

# %%
# Include all columns to see categorical data too
df.describe(include = 'all')
# Out:
#            Serial_No Fashion_type    Product_id Brand_Name      category  \
# count   24178.000000        24178  2.414400e+04      24144         24144
# unique           NaN           16           NaN        857            12
# top              NaN      T-Shirt           NaN   Roadster  men-clothing
# freq             NaN         6813           NaN       1080          8834
# mean      745.369385          NaN  2.428805e+07        NaN           NaN
# std       512.354450          NaN  6.038245e+06        NaN           NaN
# min         1.000000          NaN  1.503240e+05        NaN           NaN
# 25%       318.000000          NaN  2.163112e+07        NaN           NaN
# 50%       662.000000          NaN  2.581962e+07        NaN           NaN
# 75%      1081.000000          NaN  2.914472e+07        NaN           NaN
# max      2000.000000          NaN  3.096750e+07        NaN           NaN
#
#                                      Description        Rating Rating_count  \
# count                                      24142  21947.000000        21947
# unique                                     12650           NaN         1148
# top     Polo Collar Pure Cotton Slim Fit T-shirt           NaN     5Ratings
# freq                                         127           NaN          496
# mean                                         NaN      4.170684          NaN
# std                                          NaN      0.363585          NaN
# min                                          NaN      1.000000          NaN
# 25%                                          NaN      4.000000          NaN
# 50%                                          NaN      4.200000          NaN
# 75%                                          NaN      4.400000          NaN
# max                                          NaN      5.000000          NaN
#
#         Price_After_Discount     MRP_Price   Discount  \
# count           24154.000000  21294.000000      21283
# unique                   NaN           NaN        476
# top                      NaN           NaN  (50% OFF)
# freq                     NaN           NaN       1445
# mean             1742.143165   3228.989668        NaN
# std              1987.131462   2253.140049        NaN
# min               179.000000    299.000000        NaN
# 25%               728.000000   1659.000000        NaN
# 50%              1149.000000   2499.000000        NaN
# 75%              1974.000000   3999.000000        NaN
# max             70000.000000  19999.000000        NaN
#
#                                 size  \
# count                          21319
# unique                           526
# top     ['S', 'M', 'L', 'XL', 'XXL']
# freq                            3647
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
#                                product_description  \
# count                                        24130
# unique                                       10481
# top     The model (height 5'8) is wearing a size S
# freq                                          1614
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#                                   image_ref  \
# count                                 24142
# unique                                17224
# top     T-Shirt_women-clothing_29361726.jpg
# freq                                      4
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                                 file_path  \
# count                                               24142
# unique                                              17224
# top     C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 image_url  \
# count                                               24142
# unique                                              16802
# top     https://assets.myntassets.com/h_720,q_90,w_540...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            Specifications  \
# count                                               24134
# unique                                              10675
# top     {'Type': 'Loafers', 'Fastening': 'Slip-On', 'T...
# freq                                                  196
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                        Rating_as_stars
# count                                            20002
# unique                                           12166
# top     {'5': '5', '4': '', '3': '', '2': '', '1': ''}
# freq                                                84
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN

# %% [markdown]
# # Visualizations for Univariate Analysis

# %% [markdown]
# ## Distribution of Numerical Features

# %%
# Get the total number of unique brands
total_brands = df['Brand_Name'].nunique()
print(f'Total number of unique brands: {total_brands}')
# Out:
# Total number of unique brands: 857

# %%
fashion_types = df['Fashion_type'].unique()

for fashion in fashion_types:
    plt.figure(figsize=(6, 4))
    
    # Filter data for the current fashion type
    current_fashion = df[df['Fashion_type'] == fashion]
    
    # Get top N brands for the current fashion type
    top_brands = current_fashion['Brand_Name'].value_counts().nlargest(top_n)

    # Create the bar plot
    sns.barplot(y=top_brands.index, x=top_brands.values)
    plt.title(f'Top {top_n} Brands by Product Count in {fashion}')
    plt.xlabel('Count')
    plt.ylabel('Brand Name')
    plt.show()

# %% [markdown]
# - These are the top brands for different types of fashion types.

# %%
top_n = 10  # You can adjust this number
top_brands = df['Brand_Name'].value_counts().nlargest(top_n)

plt.figure(figsize=(12, 6))
sns.barplot(y=top_brands.index, x=top_brands.values)
plt.title(f'Top {top_n} Brands by Product Count')
plt.xlabel('Count')
plt.ylabel('Brand Name')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(y='Brand_Name', data=df, order=df['Brand_Name'].value_counts().index[:30])  # Limit to top 30 for clarity
plt.title('Top 30 Brands by Product Count')
plt.xlabel('Count')
plt.ylabel('Brand Name')
plt.show()

# %%
print(df['category'].unique())
# Out:
# ['women-clothing' 'men-clothing' 'boys-clothing' nan 'men-footwear'
#  'women-footwear' 'boys-footwear' 'girls-footwear' 'unisex-clothing'
#  'girls-clothing' 'unisex-kids-clothing' 'unisex-footwear'
#  'unisex-kids-footwear']

# %%
# Drop rows where 'category' is NaN
df = df.dropna(subset=['category'])

# Filter for women's and men's fashion types
women_fashion = df[df['category'].str.contains('women', case=False)]
men_fashion = df[df['category'].str.contains('men', case=False)]

# %%
# Calculate average ratings for each category
avg_rating = df[df['category'].str.contains('women|men', case=False)].groupby('category')['Rating_count'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=avg_rating, x='category', y='Rating_count')
plt.title('Average Rating count of Fashion Products by Gender')
plt.xlabel('Category')
plt.ylabel('Average Rating count')
plt.xticks(rotation=45)
plt.show()

# %%
avg_rating = df.groupby('category')['Rating'].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(data=avg_rating, x='category', y='Rating')
plt.title('Average Rating of Blazers by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Rating')
plt.show()

# %%
# Histogram for Actual Price
plt.figure(figsize=(10, 6))
sns.histplot(df['MRP_Price'], bins=30, kde=True)
plt.title('Distribution of MRP Price')
plt.xlabel('Actual Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram for Price
plt.figure(figsize=(10, 6))
sns.histplot(df['MRP_Price'], bins=30, kde=True)
plt.title('Distribution of Price after discount')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram for Rating
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'], bins=30, kde=True)
plt.title('Distribution of Rating')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Box Plot for Rating
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Rating'])
plt.title('Box Plot of Rating')
plt.xlabel('Rating')
plt.show()

# %%
# Box Plot for Price
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['MRP_Price'])
plt.title('Box Plot of Price')
plt.xlabel('MRP_Price')
plt.show()

# %% [markdown]
# # Count of Categorical Features

# %%
# Count Plot for Fashion Type
plt.figure(figsize=(10, 6))
sns.countplot(y='Fashion_type', data=df, order=df['Fashion_type'].value_counts().index)
plt.title('Count of Products by Fashion Type')
plt.show()

# %%
#Count Plot for Category
plt.figure(figsize=(10, 6))
sns.countplot(y='category', data=df, order=df['category'].value_counts().index)
plt.title('Count of Products by Category')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Visualizations for Bivariate Analysis

# %% [markdown]
# ## Scatter Plots for Numerical Variables

# %%
# Scatter Plot for Price vs Rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x='MRP_Price', y='Rating', data=df)
plt.title('MRP_Price vs Rating')
plt.xlabel('MRP_Price')
plt.ylabel('Rating')
plt.show()

# %%
# Scatter Plot for Rating Count vs Rating (after conversion)
df['Rating_count'] = pd.to_numeric(df['Rating_count'].str.replace('Ratings', '').str.replace(',', '').str.strip(), errors='coerce')
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Rating_count', y='Rating', data=df)
plt.title('Rating Count vs Rating')
plt.xlabel('Rating Count')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ## Box Plots for Categorical vs Numerical Variables

# %%
# Box Plot for Price by Category
plt.figure(figsize=(12, 6))
sns.boxplot(x='category', y='MRP_Price', data=df)
plt.title('Price Distribution by Category')
plt.xticks(rotation=45)
plt.show()

# %%
# Box Plot for Rating by Fashion Type
plt.figure(figsize=(12, 6))
sns.boxplot(x='Fashion_type', y='Rating', data=df)
plt.title('Rating Distribution by Fashion Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Bar Plots for Categorical Analysis

# %%
# Bar Plot for Average Rating by Category
plt.figure(figsize=(12, 6))
sns.barplot(x='category', y='Rating', data=df, estimator='mean')
plt.title('Average Rating by Category')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar Plot for Average Price by Fashion Type
plt.figure(figsize=(12, 6))
sns.barplot(x='Fashion_type', y='MRP_Price', data=df, estimator='mean')
plt.title('Average Price by Fashion Type')
plt.xticks(rotation=45)
plt.show()
