# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns

# %%
df = pd.read_csv("Trendix_Dataset.csv")
df.head()
# Out:
#    Serial_No Fashion_type  Product_id         Brand_Name        category  \
# 0          1      blazers  17464542.0                H&M  women-clothing
# 1          2      blazers  24970972.0  Allen Solly Woman  women-clothing
# 2          3      blazers  26893598.0              Arrow    men-clothing
# 3          4      blazers  28844176.0              MANGO  women-clothing
# 4          5      blazers  28774520.0              MANGO  women-clothing
#
#                                          Description  Rating Rating_count  \
# 0                          Women Black Fitted Jacket     4.4   951Ratings
# 1  Notched Lapel Collar Single-Breasted Formal Bl...     4.3   643Ratings
# 2  Notched Lapel Long Sleeves Slim-Fit Single Bre...     4.2   161Ratings
# 3                     Pure Linen Smart Casual Blazer     4.1    37Ratings
# 4  Smart Casual Linen Notched Lapel Single-Breast...     4.0    43Ratings
#
#        Price MRP_Price   Discount  \
# 0  MRP₹ 2299       MRP        NaN
# 1      ₹3959  MRP₹3999   (1% OFF)
# 2      ₹4879  MRP₹7999  (39% OFF)
# 3  MRP₹ 6790       MRP        NaN
# 4      ₹4549  MRP₹6790  (33% OFF)
#
#                                                size  \
# 0  ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL']
# 1                                               NaN
# 2              ['36', '38', '40', '42', '44', '46']
# 3         ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL']
# 4                ['XS', 'S', 'M', 'L', 'XL', 'XXL']
#
#                                  product_description  \
# 0  Fitted jacket in woven fabric with notch lapel...
# 1  Black solid regular-fit formal blazer, has a n...
# 2  Black solid slim-fit formal blazer, has a notc...
# 3  Blue solid smart casual blazer, has a peaked l...
# 4  The solid blazers for women, has notched lapel...
#
#                              image_ref  \
# 0  blazers_women-clothing_17464542.jpg
# 1  blazers_women-clothing_24970972.jpg
# 2    blazers_men-clothing_26893598.jpg
# 3  blazers_women-clothing_28844176.jpg
# 4  blazers_women-clothing_28774520.jpg
#
#                                            file_path  \
# 0  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 1  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 2  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 3  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
# 4  C:/Users/harsh/OneDrive/Desktop/AI & DS/Step 2...
#
#                                            image_url  \
# 0  https://assets.myntassets.com/h_720,q_90,w_540...
# 1  https://assets.myntassets.com/h_720,q_90,w_540...
# 2  https://assets.myntassets.com/h_720,q_90,w_540...
# 3  https://assets.myntassets.com/h_720,q_90,w_540...
# 4  https://assets.myntassets.com/h_720,q_90,w_540...
#
#                                       Specifications  \
# 0  {'Closure': 'Button', 'Collar': 'Notched Lapel...
# 1  {'Closure': 'Button', 'Collar': 'Notched Lapel...
# 2  {'Closure': 'Button', 'Collar': 'Notched Lapel...
# 3  {'Closure': 'Button', 'Collar': 'Peaked Lapel'...
# 4  {'Closure': 'Button', 'Collar': 'Notched Lapel...
#
#                                      Rating_as_stars
# 0  {'5': '645', '4': '176', '3': '62', '2': '27',...
# 1  {'5': '421', '4': '113', '3': '29', '2': '21',...
# 2  {'5': '98', '4': '29', '3': '11', '2': '9', '1...
# 3  {'5': '26', '4': '2', '3': '1', '2': '2', '1':...
# 4  {'5': '30', '4': '2', '3': '1', '2': '3', '1':...

# %%
df.shape
# There are 24178 rows and 18 columns
# Out:
# (24178, 18)

# %%
df.tail()
# Out:
#        Serial_No       Fashion_type  Product_id               Brand_Name  \
# 24173        994  Women Office Wear  30111247.0           Style Quotient
# 24174        995  Women Office Wear  27631984.0                Chemistry
# 24175        996  Women Office Wear  29328582.0  Annabelle by Pantaloons
# 24176        997  Women Office Wear  29173318.0                 Cantabil
# 24177        998  Women Office Wear  28324258.0                   FITHUB
#
#              category                               Description  Rating  \
# 24173  women-clothing           Women Smart Opaque Formal Shirt     4.0
# 24174  women-clothing                      Striped Formal Shirt     4.2
# 24175  women-clothing                 Women Opaque Formal Shirt     4.6
# 24176  women-clothing                Spread Collar Formal Shirt     4.4
# 24177  women-clothing  Women Slim Fit High-Rise Formal Trousers     3.8
#
#       Rating_count      Price MRP_Price   Discount  \
# 24173     6Ratings       ₹636  MRP₹1299  (51% OFF)
# 24174    43Ratings       ₹499  MRP₹1999  (75% OFF)
# 24175    22Ratings  MRP₹ 1499       MRP        NaN
# 24176    31Ratings       ₹899  MRP₹1999  (55% OFF)
# 24177    55Ratings       ₹899  MRP₹1999  (55% OFF)
#
#                                              size  \
# 24173                       ['S', 'M', 'L', 'XL']
# 24174                 ['XS', 'S', 'M', 'XL', 'L']
# 24175          ['XS', 'S', 'M', 'L', 'XL', 'XXL']
# 24176         ['S', 'M', 'L', 'XL', 'XXL', '3XL']
# 24177  ['30', '32', '34', '36', '38', '40', '42']
#
#                                      product_description  \
# 24173  White solid opaque Formal shirt ,has a spread ...
# 24174  Black & white vertical striped opaque formal s...
# 24175  Blue solid opaque Formal shirt ,has a spread c...
# 24176  Green solid opaque Formal shirt ,has a spread ...
# 24177  Fit: Slim FitThe model (height 5'8) is wearing...
#
#                                            image_ref  \
# 24173  Women Office Wear_women-clothing_30111247.jpg
# 24174  Women Office Wear_women-clothing_27631984.jpg
# 24175  Women Office Wear_women-clothing_29328582.jpg
# 24176  Women Office Wear_women-clothing_29173318.jpg
# 24177  Women Office Wear_women-clothing_28324258.jpg
#
#                                                file_path  \
# 24173  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24174  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24175  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24176  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24177  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
#
#                                                image_url  \
# 24173  https://assets.myntassets.com/h_720,q_90,w_540...
# 24174  https://assets.myntassets.com/h_720,q_90,w_540...
# 24175  https://assets.myntassets.com/h_720,q_90,w_540...
# 24176  https://assets.myntassets.com/h_720,q_90,w_540...
# 24177  https://assets.myntassets.com/h_720,q_90,w_540...
#
#                                           Specifications  \
# 24173  {'Sleeve Length': 'Short Sleeves', 'Collar': '...
# 24174  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24175  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24176  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24177  {'Waist Rise': 'High-Rise', 'Length': 'Regular...
#
#                                          Rating_as_stars
# 24173  {'5': '3', '4': '1', '3': '1', '2': '1', '1': ''}
# 24174  {'5': '24', '4': '11', '3': '5', '2': '', '1':...
# 24175  {'5': '16', '4': '3', '3': '3', '2': '', '1': ''}
# 24176  {'5': '21', '4': '7', '3': '', '2': '', '1': '3'}
# 24177  {'5': '28', '4': '9', '3': '6', '2': '2', '1':...

# %%
df.dtypes
# Out:
# Serial_No                int64
# Fashion_type            object
# Product_id             float64
# Brand_Name              object
# category                object
# Description             object
# Rating                 float64
# Rating_count            object
# Price                   object
# MRP_Price               object
# Discount                object
# size                    object
# product_description     object
# image_ref               object
# file_path               object
# image_url               object
# Specifications          object
# Rating_as_stars         object
# dtype: object

# %%
df.columns
# These are the available columns in the data
# Out:
# Index(['Serial_No', 'Fashion_type', 'Product_id', 'Brand_Name', 'category',
#        'Description', 'Rating', 'Rating_count', 'Price', 'MRP_Price',
#        'Discount', 'size', 'product_description', 'image_ref', 'file_path',
#        'image_url', 'Specifications', 'Rating_as_stars'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24178 entries, 0 to 24177
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Serial_No            24178 non-null  int64
#  1   Fashion_type         24178 non-null  object
#  2   Product_id           24144 non-null  float64
#  3   Brand_Name           24144 non-null  object
#  4   category             24144 non-null  object
#  5   Description          24142 non-null  object
#  6   Rating               21947 non-null  float64
#  7   Rating_count         21947 non-null  object
#  8   Price                24154 non-null  object
#  9   MRP_Price            24154 non-null  object
#  10  Discount             21283 non-null  object
#  11  size                 21319 non-null  object
#  12  product_description  24130 non-null  object
#  13  image_ref            24142 non-null  object
#  14  file_path            24142 non-null  object
#  15  image_url            24142 non-null  object
#  16  Specifications       24134 non-null  object
#  17  Rating_as_stars      20002 non-null  object
# dtypes: float64(2), int64(1), object(15)
# memory usage: 3.3+ MB

# %%
df.shape
# Out:
# (24178, 18)

# %%
# Counting null values in the dataset
null_count = df.isnull().sum()
print(null_count)
# Out:
# Serial_No                 0
# Fashion_type              0
# Product_id               34
# Brand_Name               34
# category                 34
# Description              36
# Rating                 2231
# Rating_count           2231
# Price                    24
# MRP_Price                24
# Discount               2895
# size                   2859
# product_description      48
# image_ref                36
# file_path                36
# image_url                36
# Specifications           44
# Rating_as_stars        4176
# dtype: int64

# %%
df["MRP_Price"].dtypes
# Out:
# dtype('O')

# %%
# Removing MPR from MRP_Price
df['MRP_Price'] = df['MRP_Price'].apply(lambda x: re.sub(r'[^\d]+', '', str(x)) if isinstance(x, str) else x)
df['MRP_Price'] = df['MRP_Price'].apply(lambda x: np.nan if x == '' else (int(x) if isinstance(x, str) else x))

# %%
df['MRP_Price'].dtypes
# Out:
# dtype('float64')

# %%
df.tail()
# Out:
#        Serial_No       Fashion_type  Product_id               Brand_Name  \
# 24173        994  Women Office Wear  30111247.0           Style Quotient
# 24174        995  Women Office Wear  27631984.0                Chemistry
# 24175        996  Women Office Wear  29328582.0  Annabelle by Pantaloons
# 24176        997  Women Office Wear  29173318.0                 Cantabil
# 24177        998  Women Office Wear  28324258.0                   FITHUB
#
#              category                               Description  Rating  \
# 24173  women-clothing           Women Smart Opaque Formal Shirt     4.0
# 24174  women-clothing                      Striped Formal Shirt     4.2
# 24175  women-clothing                 Women Opaque Formal Shirt     4.6
# 24176  women-clothing                Spread Collar Formal Shirt     4.4
# 24177  women-clothing  Women Slim Fit High-Rise Formal Trousers     3.8
#
#       Rating_count      Price  MRP_Price   Discount  \
# 24173     6Ratings       ₹636     1299.0  (51% OFF)
# 24174    43Ratings       ₹499     1999.0  (75% OFF)
# 24175    22Ratings  MRP₹ 1499        NaN        NaN
# 24176    31Ratings       ₹899     1999.0  (55% OFF)
# 24177    55Ratings       ₹899     1999.0  (55% OFF)
#
#                                              size  \
# 24173                       ['S', 'M', 'L', 'XL']
# 24174                 ['XS', 'S', 'M', 'XL', 'L']
# 24175          ['XS', 'S', 'M', 'L', 'XL', 'XXL']
# 24176         ['S', 'M', 'L', 'XL', 'XXL', '3XL']
# 24177  ['30', '32', '34', '36', '38', '40', '42']
#
#                                      product_description  \
# 24173  White solid opaque Formal shirt ,has a spread ...
# 24174  Black & white vertical striped opaque formal s...
# 24175  Blue solid opaque Formal shirt ,has a spread c...
# 24176  Green solid opaque Formal shirt ,has a spread ...
# 24177  Fit: Slim FitThe model (height 5'8) is wearing...
#
#                                            image_ref  \
# 24173  Women Office Wear_women-clothing_30111247.jpg
# 24174  Women Office Wear_women-clothing_27631984.jpg
# 24175  Women Office Wear_women-clothing_29328582.jpg
# 24176  Women Office Wear_women-clothing_29173318.jpg
# 24177  Women Office Wear_women-clothing_28324258.jpg
#
#                                                file_path  \
# 24173  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24174  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24175  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24176  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24177  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
#
#                                                image_url  \
# 24173  https://assets.myntassets.com/h_720,q_90,w_540...
# 24174  https://assets.myntassets.com/h_720,q_90,w_540...
# 24175  https://assets.myntassets.com/h_720,q_90,w_540...
# 24176  https://assets.myntassets.com/h_720,q_90,w_540...
# 24177  https://assets.myntassets.com/h_720,q_90,w_540...
#
#                                           Specifications  \
# 24173  {'Sleeve Length': 'Short Sleeves', 'Collar': '...
# 24174  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24175  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24176  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24177  {'Waist Rise': 'High-Rise', 'Length': 'Regular...
#
#                                          Rating_as_stars
# 24173  {'5': '3', '4': '1', '3': '1', '2': '1', '1': ''}
# 24174  {'5': '24', '4': '11', '3': '5', '2': '', '1':...
# 24175  {'5': '16', '4': '3', '3': '3', '2': '', '1': ''}
# 24176  {'5': '21', '4': '7', '3': '', '2': '', '1': '3'}
# 24177  {'5': '28', '4': '9', '3': '6', '2': '2', '1':...

# %%
null_count = df.isnull().sum()
print(null_count)
# Out:
# Serial_No                 0
# Fashion_type              0
# Product_id               34
# Brand_Name               34
# category                 34
# Description              36
# Rating                 2231
# Rating_count           2231
# Price                    24
# MRP_Price              2884
# Discount               2895
# size                   2859
# product_description      48
# image_ref                36
# file_path                36
# image_url                36
# Specifications           44
# Rating_as_stars        4176
# dtype: int64

# %%
# Removing "MRP" from 'Price' Column and converting it to integer
def extract_numerical_part(x):
    if isinstance(x, str):
        return pd.to_numeric(re.search(r'\d+', x).group(), errors='coerce')
    else:
        return x

# apply the lambda function to the 'price' column
df['Price'] = df['Price'].apply(extract_numerical_part)

# %%
df.dtypes
# Out:
# Serial_No                int64
# Fashion_type            object
# Product_id             float64
# Brand_Name              object
# category                object
# Description             object
# Rating                 float64
# Rating_count            object
# Price                  float64
# MRP_Price              float64
# Discount                object
# size                    object
# product_description     object
# image_ref               object
# file_path               object
# image_url               object
# Specifications          object
# Rating_as_stars         object
# dtype: object

# %%
df["Rating_count"]
# Out:
# 0        951Ratings
# 1        643Ratings
# 2        161Ratings
# 3         37Ratings
# 4         43Ratings
#             ...
# 24173      6Ratings
# 24174     43Ratings
# 24175     22Ratings
# 24176     31Ratings
# 24177     55Ratings
# Name: Rating_count, Length: 24178, dtype: object

# %%
# Converting 'Ratings' columns into integer.
# Filling nan values with '0'
df['Rating_count'] = df['Rating_count'].str.extract(r'(\d+)', expand=False).fillna(0).astype(int)

# %%
df.tail()
# Out:
#        Serial_No       Fashion_type  Product_id               Brand_Name  \
# 24173        994  Women Office Wear  30111247.0           Style Quotient
# 24174        995  Women Office Wear  27631984.0                Chemistry
# 24175        996  Women Office Wear  29328582.0  Annabelle by Pantaloons
# 24176        997  Women Office Wear  29173318.0                 Cantabil
# 24177        998  Women Office Wear  28324258.0                   FITHUB
#
#              category                               Description  Rating  \
# 24173  women-clothing           Women Smart Opaque Formal Shirt     4.0
# 24174  women-clothing                      Striped Formal Shirt     4.2
# 24175  women-clothing                 Women Opaque Formal Shirt     4.6
# 24176  women-clothing                Spread Collar Formal Shirt     4.4
# 24177  women-clothing  Women Slim Fit High-Rise Formal Trousers     3.8
#
#        Rating_count   Price  MRP_Price   Discount  \
# 24173             6   636.0     1299.0  (51% OFF)
# 24174            43   499.0     1999.0  (75% OFF)
# 24175            22  1499.0        NaN        NaN
# 24176            31   899.0     1999.0  (55% OFF)
# 24177            55   899.0     1999.0  (55% OFF)
#
#                                              size  \
# 24173                       ['S', 'M', 'L', 'XL']
# 24174                 ['XS', 'S', 'M', 'XL', 'L']
# 24175          ['XS', 'S', 'M', 'L', 'XL', 'XXL']
# 24176         ['S', 'M', 'L', 'XL', 'XXL', '3XL']
# 24177  ['30', '32', '34', '36', '38', '40', '42']
#
#                                      product_description  \
# 24173  White solid opaque Formal shirt ,has a spread ...
# 24174  Black & white vertical striped opaque formal s...
# 24175  Blue solid opaque Formal shirt ,has a spread c...
# 24176  Green solid opaque Formal shirt ,has a spread ...
# 24177  Fit: Slim FitThe model (height 5'8) is wearing...
#
#                                            image_ref  \
# 24173  Women Office Wear_women-clothing_30111247.jpg
# 24174  Women Office Wear_women-clothing_27631984.jpg
# 24175  Women Office Wear_women-clothing_29328582.jpg
# 24176  Women Office Wear_women-clothing_29173318.jpg
# 24177  Women Office Wear_women-clothing_28324258.jpg
#
#                                                file_path  \
# 24173  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24174  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24175  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24176  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
# 24177  C:/Users/DELL/OneDrive/Desktop/AI & DATA SCIEN...
#
#                                                image_url  \
# 24173  https://assets.myntassets.com/h_720,q_90,w_540...
# 24174  https://assets.myntassets.com/h_720,q_90,w_540...
# 24175  https://assets.myntassets.com/h_720,q_90,w_540...
# 24176  https://assets.myntassets.com/h_720,q_90,w_540...
# 24177  https://assets.myntassets.com/h_720,q_90,w_540...
#
#                                           Specifications  \
# 24173  {'Sleeve Length': 'Short Sleeves', 'Collar': '...
# 24174  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24175  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24176  {'Sleeve Length': 'Long Sleeves', 'Collar': 'S...
# 24177  {'Waist Rise': 'High-Rise', 'Length': 'Regular...
#
#                                          Rating_as_stars
# 24173  {'5': '3', '4': '1', '3': '1', '2': '1', '1': ''}
# 24174  {'5': '24', '4': '11', '3': '5', '2': '', '1':...
# 24175  {'5': '16', '4': '3', '3': '3', '2': '', '1': ''}
# 24176  {'5': '21', '4': '7', '3': '', '2': '', '1': '3'}
# 24177  {'5': '28', '4': '9', '3': '6', '2': '2', '1':...

# %%
null_count = df["Rating_count"].isnull().sum()
print(null_count)
# Out:
# 0

# %%
df.dtypes
# Out:
# Serial_No                int64
# Fashion_type            object
# Product_id             float64
# Brand_Name              object
# category                object
# Description             object
# Rating                 float64
# Rating_count             int32
# Price                  float64
# MRP_Price              float64
# Discount                object
# size                    object
# product_description     object
# image_ref               object
# file_path               object
# image_url               object
# Specifications          object
# Rating_as_stars         object
# dtype: object

# %%
# Product Count based on fashion types
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Fashion_type', order=df['Fashion_type'].value_counts().index)
plt.title('Product Count by Fashion Type')
plt.xticks(rotation=45)
plt.xlabel('Fashion Type')
plt.ylabel('Count')
plt.show()

# %%
# Creating a histogram to visualize the distribution of prices in our dataset.
plt.hist(df['Price'], bins=50, edgecolor='black')

plt.title('Histogram of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')


plt.show()

# %%
#Using scatter plots to visualize the relationships between Rating vs. Price: to see if there's a correlation between product ratings and prices.
plt.scatter(df['Rating'], df['Price'])

# Add title and labels
plt.title('Rating vs. Price')
plt.xlabel('Rating')
plt.ylabel('Price')

# Show the plot
plt.show()

# %% [markdown]
# ### We Can see as the rating of the product increases the price of the product also increased. But it is not always the case. There are lots of product with highe ratings that has lower price so thay are not strongly correlated .The product that has ratings 4 and its price is 70000 can be a outliers

# %%
#Using scatter plots to visualize the relationships between Rating vs. MRP_Prices.
plt.scatter(df['Rating'], df['Price'])

# Add title and labels
plt.title('Rating vs. MRP_Price')
plt.xlabel('Rating')
plt.ylabel('MRP_Price')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Rating'], bins=10, kde=True)
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Rating'], df['MRP_Price'])
plt.xlabel('Rating')
plt.ylabel('MRP_Price')
plt.title('Relationship between Rating and MRP Price')
plt.grid(True)
plt.show()

# %%
# Histogram for Rating
plt.subplot(1, 2, 1)
plt.hist(df['Rating'], bins=10, edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings')

# Histogram for Price
plt.subplot(1, 2, 2)
plt.hist(df['Price'], bins=10, edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Prices')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df[['Rating', 'Rating_count', 'Price', 'MRP_Price']].corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### There is no strong corelation between price and the ratings.
